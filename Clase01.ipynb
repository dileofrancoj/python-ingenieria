# %% [markdown]
# # Temario cursada
#
# ### Clase 1 (hoy)
# - Arreglos (append, remove, slicing)
# - Ciclos (for, for in)
# - If, elif, else
#
# ### Clase 2
# - Repaso de funciones y librerías
# - Numpy
# - Concepto de vectores y matrices
# - Operaciones con matrices
# - Sistemas lineales
#
# ### Clase 3: Matplotlib
# - Gráfico de funciones
# - Gráficos de dispersión
# - Como customizar un gráfico
#
# ### Clase 4 Computación simbólica
# - Concepto de computacion simbólica
# - Derivadas
# - Integrales (definidas, indefinidas e impropias)
#
# ### Clase 5 Ecuaciones diferenciales (EDO's)
# - Resolución con computación simbólica
# - Condiciones de borde
# - Algunas ecuaciones diferenciales
# - Gráficos
# - Problemas no cerrados
#
# ### Clase 6 Métodos numéricos
